# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.array([1, 2, 3, 4, 5])

# %%
x_squared = x**2

# %%
plt.plot(x, x, marker = "*")
plt.plot(x, x_squared, marker = "o")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2e611182057d> in <module>
#       1 plt.plot(x, x, marker = "*")
# ----> 2 plt.plot(x, x_squared, marker = "o")
#       3 plt.show()
#
# NameError: name 'x_squared' is not defined

# %%
X = np.random.randn(2, 2)
# Out:
# array([[ 0.34659191,  3.63437529],
#        [-1.2946551 , -2.31380508]])

# %%
x_axis = X[ :  , 2]

# %%
plt.scatter([1,5,2], [4,9,3])
plt.show()

# %%
plt.bar(19, 8)
# Out:
# <BarContainer object of 1 artists>

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
sales_of_car1 = np.array([10, 13, 8, 5, 20])
sales_of_car2 = np.array([13, 6, 9, 12, 10])

# %%
plt.bar(x, height=sales_of_car1, width = 0.3, color="orange")
plt.bar(x+0.3, height=sales_of_car2, width = 0.3, color="blue")
plt.show()

# %%
! ls
# Out:
# Basic stuff...ipynb  Matplotlibnew.ipynb  Still basics...ipynb
# Basics.ipynb         Numpy.ipynb          kushal1.jpg
# Matplotlib.ipynb     Python Basics.ipynb  kushal12.jpg

# %%
img = plt.imread("./kushal12.jpg")

# %%
img.shape
# Out:
# (1080, 1080, 3)

# %%
plt.imshow(img)
plt.show()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
meow_img = img[400:900, :600 , : ]

# %%
plt.imshow(meow_img)
plt.show()

# %%
fake_img = img.copy()

# %%
fake_img[:, : , 1] = 0

# %%
plt.imshow(fake_img)
plt.show()
